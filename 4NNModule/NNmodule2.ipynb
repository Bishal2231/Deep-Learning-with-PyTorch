# %% [markdown]
# ### 5 input for 1 hidden layer and 3 hidden layer and 1 main function ..total input:15 ,hidden layer 3 func main func then y_pred

# %%
#crate model class
import torch
import torch.nn as nn

class Model(nn.Module):
    def __init__(self,num_features):
        super().__init__()
        self.network=nn.Sequential(
            nn.Linear(num_features,3),
            nn.ReLU(),
            nn.Linear(3,1),
            nn.Sigmoid()
        
        )
    def forward(self,features):
        out=self.network(features)
    
        
        return out

# %%
#create dataser
features=torch.rand(10,5)

#create moDEL
model=Model(features.shape[1])


#call model
model(features)
# Out:
# tensor([[0.5262],
#         [0.5091],
#         [0.5097],
#         [0.5126],
#         [0.5212],
#         [0.5287],
#         [0.5218],
#         [0.5076],
#         [0.5231],
#         [0.5268]], grad_fn=<SigmoidBackward0>)

# %%
#show model weifghts
model.linear1.weight
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 #show model weifghts
# ----> 2 model.linear1.weight
#
# File c:\Users\LOQ\anaconda3\envs\bishalenv\lib\site-packages\torch\nn\modules\module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'Model' object has no attribute 'linear1'

# %%
model.linear2.weight

# %%
from torchinfo import summary
summary(model,input_size=(10,5))
